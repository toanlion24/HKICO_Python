# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def tinh_tong_phan_so_Sn():
    while True: 
        input_str = input("Nhập số nguyên dương n: ")
        try:
            n = int(input_str)
            
            if n < 1: 
                print("Vui lòng nhập số nguyên dương lớn hơn 0.")
            elif n > 10** 9:
                print("Số quá lớn, vui lòng nhập số nguyên dương nhỏ hơn hoặc bằng 10^9.")
            else:
                break
        except ValueError:
            print("Đầu vào không hợp lệ. Vui lòng nhập một số nguyên dương.")
            
    sn_value = n / (n+1)
    result_output = f"{sn_value:.2f}"
    print(f"Tổng S_n = {result_output}")
    
tinh_tong_phan_so_Sn()
# Out:
# Tổng S_n = 0.75

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try:
    n = int(input("Nhap so nguyen duong n: "))
except ValueError:
    print("Vui long nhap mot so nguyen duong.")
    exit(1)
    
if n < 1:
    print("Vui long nhap so nguyen duong lon hon 0.")
    exit(1)
if n%2 == 0:
    S_n = n // 2
else:
    S_n = -(n // 2) - 1
print(f"Giá trị của n là: {n}")
print(f"Tổng Sn là: {S_n}")
# Out:
# Giá trị của n là: 5
# Tổng Sn là: -3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try:
    # Ví dụ: Người dùng nhập "19 5"
    a, b = map(int, input("Nhập 2 số nguyên dương a và b (cách nhau bởi dấu cách): ").split())
except ValueError:
    print("Lỗi: Đầu vào không hợp lệ. Vui lòng nhập hai số nguyên dương.")
    # Kết thúc chương trình nếu nhập không đúng định dạng
    exit()
if a< b or b < 1:
    print("Lỗi: Vui lòng đảm bảo rằng a >= b và b là số nguyên dương.")
    exit()
he_so_k = a // b
ket_qua = he_so_k * b
print(f"Kết quả của phép chia lấy phần nguyên {a} chia cho {b} là: {he_so_k}")
print(f"Kết quả của phép nhân {he_so_k} với {b} là: {ket_qua}")
# Out:
# Kết quả của phép chia lấy phần nguyên 19 chia cho 5 là: 3
# Kết quả của phép nhân 3 với 5 là: 15

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# he_so_k = (a + b - 1) // b

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input("Nhập số nguyên dương n: "))
if n % 15 == 0:
    print(1)
else:
    print(0)
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
if n <= 0:
    print("INVALID")
else:
    if (n % 400 == 0) or (n % 4 == 0 and n % 100 != 0):
        print("YES")
    else:
        print("NO")
# Out:
# YES

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Cấu trúc rẽ nhánh đa nhánh (elif)
# Kiến thức: Đây là viết tắt của "else if". Nó được dùng khi bạn có nhiều điều kiện khác nhau cần kiểm tra lần lượt.
#
# Cách hoạt động: Chương trình sẽ kiểm tra điều kiện đầu tiên (if). Nếu sai, nó mới kiểm tra tiếp điều kiện elif. Nếu điều kiện elif đúng, nó thực hiện khối lệnh bên trong và bỏ qua các phần còn lại bên dưới.
#
# 2. Kiểu dữ liệu danh sách (List)
# Kiến thức: Cụm [1, 3, 5, 7, 8, 10, 12] và [4, 6, 9, 11] là các List trong Python.
#
# Ý nghĩa: Nó cho phép bạn nhóm nhiều giá trị lại với nhau vào một biến duy nhất để dễ quản lý và thao tác. Thay vì phải viết t == 1 or t == 3 or t == 5..., bạn chỉ cần gom chúng vào một danh sách.
#
# 3. Toán tử thành viên (in)
# Kiến thức: Toán tử in dùng để kiểm tra xem một giá trị có tồn tại trong một tập hợp (như List, String, Tuple) hay không.
#
# Lợi ích:
#
# Giúp code cực kỳ ngắn gọn và dễ đọc (gần giống ngôn ngữ tự nhiên: "nếu t nằm trong [danh sách này]").
#
# Thay thế cho một chuỗi dài các phép so sánh bằng (==) kết hợp với toán tử logic or.
#
# Ví dụ so sánh để bạn thấy sự khác biệt:
#
# Cách viết thông thường (dài dòng): if t == 1 or t == 3 or t == 5 or t == 7 or t == 8 or t == 10 or t == 12:
#
# Cách viết dùng in và List (tối ưu): if t in [1, 3, 5, 7, 8, 10, 12]:

# %%
t, n = map(int, input().split())

if t < 1 or t > 12 or n <= 0:
    print("INVALID")
else:
    days_map = {
        1: 31, 3: 31, 5: 31, 7: 31, 8: 31, 10: 31, 12: 31,
        4: 30, 6: 30, 9: 30, 11: 30
    }
    
    if t == 2:
       
        print(29 if (n % 400 == 0) or (n % 4 == 0 and n % 100 != 0) else 28)
    else:
       
        print(days_map[t])
# Out:
# 31

# %%
try:
    t, n = map(int, input().split())
except:
    exit()

if t < 1 or t > 12 or n <= 0:
    print("INVALID")
else:
    if t in [1, 3, 5, 7, 8, 10, 12]:
        print(31)
    elif t in [4, 6, 9, 11]:
        print(30)
    else:
        if (n % 400 == 0) or (n % 4 == 0 and n % 100 != 0):
            print(29)
        else:
            print(28)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
c = input()

if 'A' <= c <= 'Z':
    print(c.lower())
else:
    print(c)
# Out:
# %

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
next_char_code = ord(c.lower()) + 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a, b, c = map(int, input().split())

if a <= 0 or b <= 0 or c <= 0 or not (a + b > c and a + c > b and b + c > a):
    print("INVALID")
else:
    if a == b == c:
        print(1)
    elif a == b or a == c or b == c:
        print(2)
    elif a**2 == b**2 + c**2 or b**2 == a**2 + c**2 or c**2 == a**2 + b**2:
        print(3)
    else:
        print(4)
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# x1 = (-b + math.sqrt(delta)) / (2*a)
# x2 = (-b - math.sqrt(delta)) / (2*a)
# print(f"{x1:.2f} {x2:.2f}")

# %%
import math

a, b, c = map(float, input().split())

if a == 0:
    if b == 0:
        if c == 0:
            print("INF")
        else:
            print("NO")
    else:
        x = -c / b
        print(f"{x:.2f}")
else:
    delta = b**2 - 4*a*c
    if delta < 0:
        print("NO")
    elif delta == 0:
        x = -b / (2*a)
        print(f"{x:.2f}")
    else:
        x1 = (-b + math.sqrt(delta)) / (2*a)
        x2 = (-b - math.sqrt(delta)) / (2*a)
        # In nghiệm lớn trước hoặc theo thứ tự tùy đề bài, 
        # ví dụ này in x1 và x2 cách nhau dấu cách
        print(f"{x1:.2f} {x2:.2f}")
# Out:
# NO

# %% [markdown]
# ![image.png](attachment:image.png)
